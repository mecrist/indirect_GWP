# %% [markdown]
# # Global Warming Potential Pipeline
#
#  **Alice Barbarino e Maria Crist**

# %%
import matplotlib.pyplot as plt
import pandas as pd

from gwp_aux import *

# %% [markdown]
# ## Radiative Forcing from Global Mean Atmosphere with Stratospheric Temperature Adjustment.
# From the supplemetary material from Shine and Myhre 2020 [1](https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.1029/2019MS001951)

# %%
df = pd.read_csv(
    "rf_gam_1cm_adjusted.csv",
    sep=";",
    decimal=",",
    engine="python"
)

# %%
column_values = (
    df.iloc[:3000, 1]
    .astype(str)                            # ensure all entries are strings
    .str.replace(',', '.', regex=False)     # fix decimal separator
    .str.replace(' ', '', regex=False)      # remove stray spaces
)

RF_gam = pd.to_numeric(column_values, errors='coerce').to_numpy()

RF_gam *= 1e15

# %% [markdown]
# ## Loading IR data from DFT calculation

# %%
#ORDEM: BASE_FUNCIONAL_TRATAAMENTO
g631_b3_hr = '6-31G**/B3LYP_harm/orca.out'
g631_pw6_hr = "6-31G**/PW6B95_harm/orca.out"


jun_b3_hr = "jun-cc-pv/B3LYP_harm/orca.out"
jun_pw6_hr = "jun-cc-pv/PW6B95_harm/orca.out"

g6311_b3_hr = '6-311++G**/B3LYP_harm/orca.out'
g6311_pw_hr = '6-311++G**/PW6B95_harm/orca.out'

orcas = [g631_b3_hr, g631_pw6_hr, jun_b3_hr, jun_pw6_hr, g6311_b3_hr, g6311_pw_hr]

# %%
## Radiative Efficiency and Global Warning Potential Calculation

RE_ch2f2_ipcc = 0.111

for o in orcas:
    #plotting
    r = plot_ir_spectrum(
        o,
        hwhm=30.0,
        scale_to_cm_molecule=True,
        save_plot=True,
        filename=o
    )

    #frequencies and intensities
    freqs = r[4]
    intensities = r[5]

    bin_centers, integrated_intensities = integrated_cross_section(intensities, freqs)

    # radiative efficiency and GWP
    RE = calculate_radiative_efficiency(integrated_intensities, RF_gam, tau=5.23, degradation_type='OH')
    GWP = calculate_gwp(RE, tau=5.23, molar_mass=52.02e-3, horizons=[20, 100, 500])

    # comparasion with IPCC reference
    abs_error = RE - RE_ch2f2_ipcc
    rel_error = (abs_error / RE_ch2f2_ipcc) * 100

    print(f"Treatment: {o}")
    print(f"Radiative efficiency (calc): {RE:.6f} W/m²/ppb")
    print(f"IPCC $CH_2F_2$ RE: {RE_ch2f2_ipcc:.6f}")
    print(f"Abs error: {abs_error:.6e}, Rel error: {rel_error:.2f}%")
    print(f"GWP (20,100,500): {GWP}")
    print("-" * 50)
# Out:
# Saved plot: 6-31G**_B3LYP_harm_orca.out_IRspectrum.png
# Treatment: 6-31G**/B3LYP_harm/orca.out
# Radiative efficiency (calc): 0.091514 W/m²/ppb
# IPCC $CH_2F_2$ RE: 0.111000
# Abs error: -1.948554e-02, Rel error: -17.55%
# GWP (20,100,500): {'GWP_20yr': np.float64(2083.461551931024), 'AGWP_gas_20yr': np.float64(50.62811571192388), 'GWP_100yr': np.float64(578.3064751747481), 'AGWP_gas_100yr': np.float64(51.758429528139956), 'GWP_500yr': np.float64(164.835763647203), 'AGWP_gas_500yr': np.float64(51.75842978522174)}
# --------------------------------------------------
# Saved plot: 6-31G**_PW6B95_harm_orca.out_IRspectrum.png
# Treatment: 6-31G**/PW6B95_harm/orca.out
# Radiative efficiency (calc): 0.085310 W/m²/ppb
# IPCC $CH_2F_2$ RE: 0.111000
# Abs error: -2.568961e-02, Rel error: -23.14%
# GWP (20,100,500): {'GWP_20yr': np.float64(1942.2167114131846), 'AGWP_gas_20yr': np.float64(47.195866087340384), 'GWP_100yr': np.float64(539.1011412530424), 'AGWP_gas_100yr': np.float64(48.249552142147294), 'GWP_500yr': np.float64(153.66099484649885), 'AGWP_gas_500yr': np.float64(48.24955238180064)}
# --------------------------------------------------
# Saved plot: jun-cc-pv_B3LYP_harm_orca.out_IRspectrum.png
# Treatment: jun-cc-pv/B3LYP_harm/orca.out
# Radiative efficiency (calc): 0.103108 W/m²/ppb
# IPCC $CH_2F_2$ RE: 0.111000
# Abs error: -7.891727e-03, Rel error: -7.11%
# GWP (20,100,500): {'GWP_20yr': np.float64(2347.41172497511), 'AGWP_gas_20yr': np.float64(57.04210491689516), 'GWP_100yr': np.float64(651.5711313203891), 'AGWP_gas_100yr': np.float64(58.315616253174824), 'GWP_500yr': np.float64(185.7185240217384), 'AGWP_gas_500yr': np.float64(58.31561654282586)}
# --------------------------------------------------
# Saved plot: jun-cc-pv_PW6B95_harm_orca.out_IRspectrum.png
# Treatment: jun-cc-pv/PW6B95_harm/orca.out
# Radiative efficiency (calc): 0.079485 W/m²/ppb
# IPCC $CH_2F_2$ RE: 0.111000
# Abs error: -3.151507e-02, Rel error: -28.39%
# GWP (20,100,500): {'GWP_20yr': np.float64(1809.5916124868484), 'AGWP_gas_20yr': np.float64(43.973076183430415), 'GWP_100yr': np.float64(502.2883892208749), 'AGWP_gas_100yr': np.float64(44.9548108352683), 'GWP_500yr': np.float64(143.16818808457583), 'AGWP_gas_500yr': np.float64(44.954811058556814)}
# --------------------------------------------------
# Saved plot: 6-311++G**_B3LYP_harm_orca.out_IRspectrum.png
# Treatment: 6-311++G**/B3LYP_harm/orca.out
# Radiative efficiency (calc): 0.113147 W/m²/ppb
# IPCC $CH_2F_2$ RE: 0.111000
# Abs error: 2.146597e-03, Rel error: 1.93%
# GWP (20,100,500): {'GWP_20yr': np.float64(2575.9489606742204), 'AGWP_gas_20yr': np.float64(62.59555974438356), 'GWP_100yr': np.float64(715.0062175598442), 'AGWP_gas_100yr': np.float64(63.99305647160606), 'GWP_500yr': np.float64(203.79954391546713), 'AGWP_gas_500yr': np.float64(63.99305678945668)}
# --------------------------------------------------
# Saved plot: 6-311++G**_PW6B95_harm_orca.out_IRspectrum.png
# Treatment: 6-311++G**/PW6B95_harm/orca.out
# Radiative efficiency (calc): 0.122136 W/m²/ppb
# IPCC $CH_2F_2$ RE: 0.111000
# Abs error: 1.113581e-02, Rel error: 10.03%
# GWP (20,100,500): {'GWP_20yr': np.float64(2780.601546651522), 'AGWP_gas_20yr': np.float64(67.56861758363198), 'GWP_100yr': np.float64(771.8116409775396), 'AGWP_gas_100yr': np.float64(69.07714186748979), 'GWP_500yr': np.float64(219.99089875984976), 'AGWP_gas_500yr': np.float64(69.07714221059283)}
# --------------------------------------------------
